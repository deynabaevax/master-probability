# %%
import pandas as pd

# %%
df_filtered = pd.read_excel('SO-data.xlsx', sheet_name='Sheet1')

# %%
# Filter the data to exclude entries from the year 2023
df = df_filtered[df_filtered['Basic_start_date_timestamp_utc'].dt.year != 2023]

# Display the filtered DataFrame
df
# Out:
#        Equipment_number PRODUCTLINE_CODE COMMERCIALTYPE CS_SITE_CLUSTER_NAME  \
# 37615              ED61               XT        XT:860M       SK Hynix Ichon
# 37619              9538               XT        XT:860M       SEC Foundry HS
# 37620              9538               XT        XT:860M       SEC Foundry HS
# 37621              6984               XT      XT:1950HI           SEC Mem H3
# 37622              KW24               XT        XT:860M   SK Hynix Cheong Ju
# ...                 ...              ...            ...                  ...
# 100118             8407               XT        XT:860H           SEC Mem H3
# 100119             6029               XT        XT:875F           SEC Mem H1
# 100120             6471               XT        XT:860L           SEC Mem H3
# 100121             8407               XT        XT:860H           SEC Mem H3
# 100122             6471               XT        XT:860L           SEC Mem H3
#
#        CS_SITE_REGION_NAME    Functional_location  \
# 37615                Korea      SKHYNIX-A-ICH-M16
# 37619                Korea       SAMSUNG-A-KIH-S3
# 37620                Korea       SAMSUNG-A-KIH-S3
# 37621                Korea      SAMSUNG-A-TAE-L17
# 37622                Korea  SKHYNIX-A-CHE-FAB M15
# ...                    ...                    ...
# 100118               Korea      SAMSUNG-A-TAE-L16
# 100119               Korea  SAMSUNG-A-TAE-LINE 13
# 100120               Korea      SAMSUNG-A-TAE-L17
# 100121               Korea      SAMSUNG-A-TAE-L16
# 100122               Korea      SAMSUNG-A-TAE-L17
#
#        Notification_sms_software_release  Order_number  \
# 37615                              5.1.0      52712563
# 37619                              5.1.0      52712501
# 37620                              5.1.0      52712439
# 37621                              5.0.0      52712378
# 37622                              5.1.0      52712276
# ...                                  ...           ...
# 100118                             5.0.0      52919178
# 100119                             4.1.0      52888905
# 100120                             5.0.0      52932157
# 100121                             5.0.0      52919179
# 100122                             5.0.0      52932158
#
#         Number_of_superior_order Maintenance_activity_type_description  \
# 37615                        NaN                               Service
# 37619                        NaN                           System Down
# 37620                        NaN                           System Down
# 37621                        NaN                           System Down
# 37622                        NaN                     Intermittent Down
# ...                          ...                                   ...
# 100118                       NaN                          Deinstall FP
# 100119                       NaN                          Deinstall FP
# 100120                       NaN                          Deinstall FP
# 100121                       NaN                          Reinstall FP
# 100122                       NaN                          Reinstall FP
#
#                                   Description Notification_sms_errorcode  \
# 37615                               TEST_WTQT                        NaN
# 37619   [ESC]Some Dir in Service_data deleted                        NaN
# 37620                    [USD]PSAKA08 MU-110D                    MU-110D
# 37621                           [USD] WI-B715                    WI-B715
# 37622             [Comp only]Dynamic Ch2 MA Y                        NaN
# ...                                       ...                        ...
# 100118      UR_RL_DI of M8407 from L16 to L16                        NaN
# 100119   UR_RL_DI of m6029 from 13L (DI only)                        NaN
# 100120     UR_RL_DI of M6471 from 16-2 to L17                        NaN
# 100121      UR_RL_RI of M8407 from L16 to L16                        NaN
# 100122     UR_RL_RI of M6471 from 16-2 to L17                        NaN
#
#        Notification_rootcause Notification_improvement_proposal  \
# 37615                     NaN                               NaN
# 37619                     NaN                               NaN
# 37620                     NaN                               NaN
# 37621                     NaN                               NaN
# 37622                     NaN                               NaN
# ...                       ...                               ...
# 100118                    NaN                               NaN
# 100119                    NaN                               NaN
# 100120                    NaN                               NaN
# 100121                    NaN                               NaN
# 100122                    NaN                               NaN
#
#        Basic_start_date_timestamp_utc Basic_finish_date_timestamp_utc  \
# 37615             2024-01-01 22:36:00             2024-01-01 22:36:00
# 37619             2024-01-01 17:22:00             2024-01-01 17:22:00
# 37620             2024-01-01 16:58:00             2024-01-01 16:58:00
# 37621             2024-01-01 14:39:00             2024-01-01 14:39:00
# 37622             2024-01-01 06:09:00             2024-01-01 06:09:00
# ...                               ...                             ...
# 100118            2025-03-16 23:00:00             2025-03-30 14:30:00
# 100119            2025-03-16 23:00:00             2025-03-30 14:30:00
# 100120            2025-03-30 22:00:00             2025-04-13 14:30:00
# 100121            2025-03-30 22:00:00             2025-05-04 14:30:00
# 100122            2025-04-13 22:00:00             2025-05-18 14:30:00
#
#        Highest_escalation_level
# 37615                       NaN
# 37619                       NaN
# 37620                       NaN
# 37621                       NaN
# 37622                       NaN
# ...                         ...
# 100118                      NaN
# 100119                      NaN
# 100120                      NaN
# 100121                      NaN
# 100122                      NaN
#
# [62486 rows x 17 columns]

# %%
# df = pd.read_excel('SO-data.xlsx', sheet_name='Sheet1')

# %% [markdown]
# Text Mining on the IFM Scaling Nodes

# %%
# Find rows containing power aom
power_aom_df = df[df['Description'].str.contains('power aom|aom', case=False, na=False)]
power_aom_df
# Out:
#       Equipment_number PRODUCTLINE_CODE COMMERCIALTYPE CS_SITE_CLUSTER_NAME  \
# 37649             9491               XT        XT:860M            HVM 200mm
# 37780             GJ27               XT        XT:860N                 SIEN
# 37904             4017               XT      XT:1700FI            TSMC F14A
# 38050             4069               XT      XT:1950HI         GF Singapore
# 38088             EO79               XT        XT:860M            TSMC F18B
# ...                ...              ...            ...                  ...
# 99905             5649               XT        XT:870F            Micron F6
# 99916             7313               XT       XT:1460K          Micron F10A
# 99975             8414               XT        XT:850F        Sony Kumamoto
# 99976             3788               XT       XT:1450H        Sony Kumamoto
# 99988             HI72               XT        XT:860N       SEC Foundry PT
#
#       CS_SITE_REGION_NAME           Functional_location  \
# 37649              Taiwan  VISERA -A-HSI-VISERA HSINCHU
# 37780               China           SIEN   -A-QIN-FAB B
# 37904              Taiwan      TSMC   -A-TAI-FAB 14A P7
# 38050           Singapore           GLOBALF-A-SIN-FAB 7
# 38088              Taiwan     TSMC   -A-TAI-FAB 18B P6A
# ...                   ...                           ...
# 99905                  US           MICRON -U-MAN-FAB 6
# 99916           Singapore         MICRON -A-SIN-FAB 10A
# 99975               Japan  SONY   -A-KIK-KUMAMOTO TECHN
# 99976               Japan  SONY   -A-KIK-KUMAMOTO TECHN
# 99988               Korea             SAMSUNG-A-PYE-P3L
#
#       Notification_sms_software_release  Order_number  \
# 37649                             5.0.0      52712551
# 37780                             5.1.0      52713251
# 37904                             5.1.0      52712969
# 38050                             5.1.0      52713195
# 38088                             5.1.0      52714244
# ...                                 ...           ...
# 99905                             4.1.0      52945409
# 99916                             5.1.0      52945999
# 99975                             4.1.0      52945680
# 99976                             5.0.0      52945663
# 99988                             5.1.0      52945630
#
#        Number_of_superior_order Maintenance_activity_type_description  \
# 37649                       NaN                               Service
# 37780                       NaN                               Service
# 37904                       NaN                           System Down
# 38050                       NaN                     Potential Problem
# 38088                       NaN                     Intermittent Down
# ...                         ...                                   ...
# 99905                       NaN                               Service
# 99916                       NaN                     Intermittent Down
# 99975                       NaN                     Potential Problem
# 99976                       NaN                     Potential Problem
# 99988                       NaN                               Service
#
#                                    Description Notification_sms_errorcode  \
# 37649   [TPMS-MTBI] AOM LASER HEALTH MONITOR#W                        NaN
# 37780          [SD]MI-5F19_rebalance AOM laser                    MI-5F19
# 37904                   [MTBI-T] ADJ AOM laser                        NaN
# 38050                   AOM_ROC_negative_value                        NaN
# 38088                     [CID] AOM tool order                        NaN
# ...                                        ...                        ...
# 99905  TPMS_AOM_Peak_and_Balance_/_AOM_Replace                        NaN
# 99916    MI-5F1D cause MO-810A error AOM laser                    MI-5F1D
# 99975       SD_OT_TPMS_AOM_EsideX3_MsideZ1_low                        NaN
# 99976     SD_OT_TPMS_AOM_Z2_Eside_Z2_Mside_low                        NaN
# 99988                    SD_OT_AOM reservation                        NaN
#
#           Notification_rootcause Notification_improvement_proposal  \
# 37649                        NaN                               NaN
# 37780                        NaN                               NaN
# 37904                        NaN                               NaN
# 38050                        NaN                               NaN
# 38088                        NaN                               NaN
# ...                          ...                               ...
# 99905                        NaN                               NaN
# 99916   Out of WS GREEN range on                               NaN
# 99975                        NaN                               NaN
# 99976                        NaN                               NaN
# 99988                        NaN                               NaN
#
#       Basic_start_date_timestamp_utc Basic_finish_date_timestamp_utc  \
# 37649            2024-01-01 20:34:00             2024-01-01 20:34:00
# 37780            2024-01-02 07:55:00             2024-01-02 07:55:00
# 37904            2024-01-02 03:46:00             2024-01-02 03:46:00
# 38050            2024-01-02 07:41:00             2024-01-02 07:41:00
# 38088            2024-01-03 07:16:00             2024-01-03 07:16:00
# ...                              ...                             ...
# 99905            2024-10-08 12:54:00             2024-10-08 12:54:00
# 99916            2024-10-09 07:18:00             2024-10-09 07:18:00
# 99975            2024-10-09 00:19:00             2024-10-09 00:19:00
# 99976            2024-10-09 00:40:00             2024-10-09 00:40:00
# 99988            2024-10-08 23:55:00             2024-10-08 23:55:00
#
#       Highest_escalation_level
# 37649                      NaN
# 37780                      NaN
# 37904                      NaN
# 38050                      NaN
# 38088                      NaN
# ...                        ...
# 99905                      NaN
# 99916                      NaN
# 99975                      NaN
# 99976                      NaN
# 99988                      NaN
#
# [658 rows x 17 columns]

# %%
# Find rows containing motor temp
motor_temp_df = df[df['Description'].str.contains('motor temp', case=False, na=False)]
motor_temp_df
# Out:
#       Equipment_number PRODUCTLINE_CODE COMMERCIALTYPE CS_SITE_CLUSTER_NAME  \
# 57345             8258               XT      XT:1900GI           SEC Mem H1
# 60125             9010               XT        XT:875F       SEC Foundry KH
# 62640             EB89               XT        XT:860M          TSMC CHUNAN
# 62726             EE91               XT       XT:1060K                  HFC
# 91436             BS85               XT        XT:400L            TSMC F18B
# 97635             9186               XT        XT:860H           SEC Mem H3
#
#       CS_SITE_REGION_NAME        Functional_location  \
# 57345               Korea      SAMSUNG-A-TAE-LINE 13
# 60125               Korea           SAMSUNG-A-KIH-S1
# 62640              Taiwan       TSMC   -A-HSI-CHUNAN
# 62726               China          HFCSEMI-A-HAN-FAB
# 91436              Taiwan  TSMC   -A-TAI-FAB 18B P8A
# 97635               Korea          SAMSUNG-A-TAE-L17
#
#       Notification_sms_software_release  Order_number  \
# 57345                             5.0.0      52787636
# 60125                             4.1.0      52797186
# 62640                             5.1.0      52806714
# 62726                             5.1.0      52806963
# 91436                             5.1.0      52914206
# 97635                             5.0.0      52936629
#
#        Number_of_superior_order Maintenance_activity_type_description  \
# 57345                       NaN                           System Down
# 60125                       NaN                           System Down
# 62640                       NaN                     Potential Problem
# 62726                       NaN                     Potential Problem
# 91436                       NaN                     Intermittent Down
# 97635                       NaN                     Potential Problem
#
#                                  Description Notification_sms_errorcode  \
# 57345           UD_LA_Ch2 XYmotor temp issue                    WS-1B04
# 60125            PI_OT_C1 XY motor temp high                        NaN
# 62640  [POTE] FDC_WsSsMotor TempSenssor jump                        NaN
# 62726   [MIB] SS XY motor temp jump_EE91_HFC                        NaN
# 91436   [CID] RS-2ACA SS motor temp too high                    RS-2ACA
# 97635          PI_OT_LSE motor temp too high                        NaN
#
#       Notification_rootcause Notification_improvement_proposal  \
# 57345                    NaN                               NaN
# 60125                    NaN                               NaN
# 62640                    NaN                               NaN
# 62726                    NaN                               NaN
# 91436                    NaN                               NaN
# 97635                    NaN                               NaN
#
#       Basic_start_date_timestamp_utc Basic_finish_date_timestamp_utc  \
# 57345            2024-04-02 10:13:00             2024-04-02 10:13:00
# 60125            2024-04-13 01:46:00             2024-04-13 01:46:00
# 62640            2024-04-24 07:53:00             2024-04-24 07:53:00
# 62726            2024-04-24 09:52:00             2024-04-24 09:52:00
# 91436            2024-08-30 01:37:00             2024-08-30 01:37:00
# 97635            2024-09-26 22:35:00             2024-09-26 22:35:00
#
#                    Highest_escalation_level
# 57345                                   NaN
# 60125   2-TSE/Local (Tech Support Engineer)
# 62640  2-TSE/Remote (Tech Support Engineer)
# 62726                                   NaN
# 91436                                   NaN
# 97635   2-TSE/Local (Tech Support Engineer)

# %%
# Find rows containing airshowers
air_showers_df = df[df['Description'].str.contains('airshowers|airshower', case=False, na=False)]
air_showers_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing pneumatic loop
pneumatic_loop_df = df[df['Description'].str.contains('pneumatic loop|pneumatic', case=False, na=False)]
pneumatic_loop_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing cam monitoring
cam_monitoring_df = df[df['Description'].str.contains('cam monitoring', case=False, na=False) 
                                & df['Description'].str.contains('ifm', case=False, na=False)]
cam_monitoring_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing ACC_CAF_HEALTH_MONITOR
acc_caf_health_mon_df = df[df['Description'].str.contains('ACC_CAF_HEALTH_MONITOR', case=False, na=False)]
acc_caf_health_mon_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing metroframe temp
metroframe_temp_df = df[df['Description'].str.contains('metroframe temp', case=False, na=False)]
metroframe_temp_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing los airbearing
los_airbearing_df = df[df['Description'].str.contains('los airbearing', case=False, na=False)]
los_airbearing_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing ss2 temp
ss2_temp_df = df[df['Description'].str.contains('ss2 temp', case=False, na=False)]
ss2_temp_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing ss1 temp
ss1_temp_df = df[df['Description'].str.contains('ss1 temp', case=False, na=False)]
ss1_temp_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing quick stop ws
quick_stop_ws_df = df[df['Description'].str.contains('Quick Stop WS', case=False, na=False)]
quick_stop_ws_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing TIS_Mark Health (Athena)
tis_mark_health_ath_df = df[df['Description'].str.contains('TIS_Mark Health', case=False, na=False)]
tis_mark_health_ath_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing TIS_Mark Health (Smash)
tis_mark_health_smsh_df = df[df['Description'].str.contains('TIS_Mark Health', case=False, na=False)]
tis_mark_health_smsh_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing Reticle Alignment
reticle_alignment_df = df[df['Description'].str.contains('Reticle Alignment', case=False, na=False)]
reticle_alignment_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing Air humidity
air_humidity_df = df[df['Description'].str.contains('air humidity', case=False, na=False)]
air_humidity_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing instable wavelength
instable_wavelength_df = df[df['Description'].str.contains('instable wavelength|wavelength', case=False, na=False)]
instable_wavelength_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
# Find rows containing pressure baro
pressure_baro_df = df[df['Description'].str.contains('pressure baro', case=False, na=False)]
pressure_baro_df
# Out:
# Empty DataFrame
# Columns: [Equipment_number, CS_SITE_REGION_NAME, Order_number, Maintenance_activity_type_description, Description, Basic_start_date_timestamp_utc, Basic_finish_date_timestamp_utc]
# Index: []

# %%
import matplotlib.pyplot as plt

# List of dataframes and their names excluding 'df'
dataframes = [
    ('acc_caf_health_mon_df', acc_caf_health_mon_df),
    ('air_humidity_df', air_humidity_df),
    ('air_showers_df', air_showers_df),
    ('cam_monitoring_df', cam_monitoring_df),
    ('los_airbearing_df', los_airbearing_df),
    ('metroframe_temp_df', metroframe_temp_df),
    ('motor_temp_df', motor_temp_df),
    ('pressure_baro_df', pressure_baro_df),
    ('quick_stop_ws_df', quick_stop_ws_df),
    ('reticle_alignment_df', reticle_alignment_df),
    ('ss1_temp_df', ss1_temp_df),
    ('ss2_temp_df', ss2_temp_df),
    ('tis_mark_health_ath_df', tis_mark_health_ath_df),
    ('tis_mark_health_smsh_df', tis_mark_health_smsh_df),
    ('instable_wavelength_df', instable_wavelength_df),
    ('pneumatic_loop_df', pneumatic_loop_df),
    ('power_aom_df', power_aom_df),
]

# Get the number of instances in each dataframe
counts = [(name, len(dfs)) for name, dfs in dataframes]

# Sort the counts by the number of instances
counts.sort(key=lambda x: x[1], reverse=True)

# Create the bar chart
names, values = zip(*counts)
plt.figure(figsize=(10, 6))
plt.bar(names, values)
plt.xlabel('Dataframe Name')
plt.ylabel('Number of Instances')
plt.title('Number of Instances in Each Dataframe')
plt.xticks(rotation=90)
plt.show()
