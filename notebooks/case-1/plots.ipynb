# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('SO-observ.xlsx', sheet_name='comparison-table')

# %%
import matplotlib as mpl

# Set the default font family
mpl.rcParams['font.family'] = 'serif'

accuracy = [0, 20, 30, 40, 45, 44, 43]

plt.plot(df, accuracy, marker='o', linestyle='-', color='blue', label="Accuracy")

for metric, values in zip(['Accuracy'], [accuracy]):
    for x, y in zip(samples, values):
        plt.text(x, y + 0.5, f"{y}%", fontsize=12, ha='center', color='black', fontdict={'family': 'serif'})

plt.title("Accuracy vs. Number of Samples", fontsize=12, fontdict={'family': 'serif'})
plt.xlabel("Number of Samples", fontsize=12, fontdict={'family': 'serif'})
plt.ylabel("Metric (accuracy %)", fontsize=14, fontdict={'family': 'serif'})
plt.yticks(range(0, 51, 10))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Make a plot of the rest of the metrics
precision = [0, 33, 40, 50, 55, 50]
recall = [0, 33, 36, 33, 50, 43]
f1_score = [0, 33, 36, 40, 52, 46]

plt.plot(steps, precision, marker='o', linestyle='-', color='green', label="Precision")
plt.plot(steps, recall, marker='o', linestyle='-', color='red', label="Recall")
plt.plot(steps, f1_score, marker='o', linestyle='-', color='purple', label="F1 Score")

for metric, values in zip(['Precision', 'Recall', 'F1 Score'], [precision, recall, f1_score]):
    for x, y in zip(steps, values):
        plt.text(x, y + 0.5, f"{y}%", fontsize=10, ha='center', color='black')

plt.title("Metrics vs. Number of Samples", fontsize=12, fontdict={'family': 'serif'})
plt.xlabel("Number of Samples", fontsize=12, fontdict={'family': 'serif'})
plt.ylabel("Metric (Precision, Recall, F1-Score %)", fontsize=14, fontdict={'family': 'serif'})
plt.yticks(range(0, 51, 10))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()
